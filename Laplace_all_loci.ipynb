# %%
import numpy as np
import tensorflow as tf
import pylab
# %matplotlib inline

from tensorflow.python.framework import ops
from tensorflow.python.ops import gen_nn_ops
from random import shuffle # For shuffling start position list

import cPickle as pickle
import time
import scipy.optimize as opt

# %%
# This is the same as the normal notebook. Here, also the mean allele frequencies
# are estimated
#

# %%
nr_inds = 600 # Nr. of Individuals to Check

#X_data = np.loadtxt('./coordinates10.csv', delimiter='$').astype('float64') # Load the complete X-Data
#Y_data = np.loadtxt('./data_genotypes10.csv', delimiter='$').astype('float64') # Load the complete Y-Data

path1 = "data_lists.p"  # Load data from pickle file!
x_data_sets, y_data_sets  = pickle.load(open(path1, "rb"))  # Load data from pickle file!
print("Length of Data-Set: ")
print(len(x_data_sets))

data_set_nr=1
X_data=x_data_sets[data_set_nr]
Y_data=y_data_sets[data_set_nr]

#print(len(X_data))
inds=range(len(X_data))
shuffle(inds)  # Random permutation of the indices. If not random draw - comment out
inds=inds[:nr_inds]  # Only load first nr_inds


# Only load first nr_inds entries
X_data = X_data[inds,:]
#X_data = np.array([[1,1],[1,0],[-1,1],[-1,0]])   # For debugging
Y_data = Y_data[inds,:]
#Y_data = np.array([[0, 1], [0, 0],[1, 1], [0, 0]])



#./data_genotypes5.csv has mean p=0.2
assert(len(X_data) == len(Y_data))

N = X_data.shape[0]
k = X_data.shape[1]
print("Dim. of X-data: %i x %i" % (N,k))
M1 = Y_data.shape[0]
nr_loci = Y_data.shape[1]


p_mean = np.mean(Y_data, axis=0) # Empirical average for every loci
#p_mean=np.mean(Y_data)
print("Mean p: ")
print(p_mean)

# Change this for coordinates5.csv  (If mean is known)
#f_mean = np.loadtxt('./mean_f6.csv', delimiter='$').astype('float64')[inds]   # Empirical f_mean
#f_mean = np.log(p_mean) - np.log(1 - p_mean) # Does a Logit Transform
#f_mean=np.log(0.2)-np.log(1.0-0.2)   # If known

#print(len(f_mean))
#print(len(f_mean))
Y_data[Y_data < 0.5] = -1.0  # For the logit Link function
print("Dim. of Y-data: %i x %i" % (M1, nr_loci))

#mean_paramss = np.array([f_mean for _ in range(nr_loci)]) # Initial Parameter for the mean-parameters
#mean_paramss = np.array([0.0 for _ in range(nr_loci)])  # Set everything to 0
mean_paramss = np.array([np.pi/2.0 for _ in range(nr_loci)])  # Set everything to 0.5. For ArcSin Model
#mean_paramss = np.array(f_mean)
print("Assumed f-mean:")
print(mean_paramss[:10])

# Plot the data
pylab.figure()
pylab.title("Sample Distribution", fontsize=30)
pylab.scatter(X_data[:,0], X_data[:,1], label = "Samples",s=50)
pylab.vlines(0, min(X_data[:,1]), max(X_data[:,1]),linewidth=2, color="red", label="Barrier")
pylab.xlabel("X-Coordinate", fontsize=30)
pylab.ylabel("Y-Coordinate", fontsize=30)
pylab.xlim([-22,22])
pylab.ylim([-30,30])
pylab.tick_params(axis='both', which='both', bottom='off', 
                    top='off', labelbottom='off', right='off', left='off', labelleft='off')
#pylab.legend(fontsize=20)
pylab.show()
# Out:
# Length of Data-Set:
# 80
# Dim. of X-data: 500 x 2
# Mean p:
# [ 0.514  0.538  0.438  0.45   0.466  0.402  0.418  0.556  0.46   0.464
#   0.606  0.484  0.53   0.534  0.512  0.484  0.536  0.504  0.458  0.51
#   0.552  0.462  0.53   0.426  0.518  0.474  0.498  0.46   0.474  0.514
#   0.494  0.512  0.5    0.446  0.544  0.356  0.494  0.456  0.566  0.51
#   0.528  0.524  0.532  0.574  0.532  0.51   0.474  0.46   0.602  0.512
#   0.458  0.564  0.528  0.506  0.542  0.512  0.556  0.51   0.562  0.56
#   0.502  0.56   0.454  0.48   0.482  0.534  0.56   0.558  0.544  0.486
#   0.496  0.498  0.476  0.528  0.482  0.486  0.534  0.456  0.45   0.484
#   0.462  0.46   0.492  0.498  0.526  0.502  0.498  0.482  0.492  0.568
#   0.53   0.494  0.52   0.55   0.584  0.508  0.466  0.456  0.498  0.506]
# Dim. of Y-data: 500 x 100
# Assumed f-mean:
# [ 1.57079633  1.57079633  1.57079633  1.57079633  1.57079633  1.57079633
#   1.57079633  1.57079633  1.57079633  1.57079633]

# %%
###### The Full Kernel:
def full_kernel_function(coords, l, a, c):
    '''Return barrier Kernel - describing reduced correlation across barrier
    and increased correlation next to barrier. Coords is nx2 Numpy array.
    Barrier is assumed to be at x=0'''
    x = coords[:, 0]  # Extracts x-coords
    
    mask = tf.constant([-1.0, 1.0], dtype=tf.float64) # Mask used for reflecting coordinates
    
    coords_refl = coords * mask[None,:]  # Reflects the x-Coordinate
    
    g = tf.sign(x)  # Calculates Signum of x
    same_side = (g[:,None] * g + 1) / 2  # Whether the x-Values are on the same side
    #print("Same Side Vector: ")
    #print(same_side)
    
    r_sqrd = tf.reduce_sum(((coords[:, None] - coords[None, :]) ** 2), reduction_indices=[2])  # Calculates pairwise Distance
    r_refl_sqrd = tf.reduce_sum(((coords_refl[:, None] - coords[None, :]) ** 2), reduction_indices=[2])  # Calculates the reflected Distance 
    
    # Calculate the normal Kernel:
    cov_mat = a * tf.exp(-r_sqrd / (2. * l ** 2))  # Calculate the co-variance matrix. Added diagonal term
    cov_mat_refl = a * tf.exp(-r_refl_sqrd / (2. * l ** 2))  # Calculate the covariance matrix for reflected coordinates.
    K = same_side * (cov_mat + c * cov_mat_refl) + (1 - same_side) * (1 - c) * cov_mat
    
    #print("Covariance Matrix: ")
    #print(cov_tot)
    #print("Eigenvalues: ")
    #print(np.linalg.eig(cov_mat)[0])
    return K

def rbf_kernel_function(coords, l, a):
    '''The usual exponential kernel function'''
    K = a * tf.exp(-tf.reduce_sum(((coords[:, None] - coords[None, :]) ** 2) / (2 * l**2), reduction_indices=[2]))
    return K

# %%
# From Alex: To calculate the log determinant

def py_func(func, inp, Tout, stateful=True, name=None, grad=None):
    
    # Need to generate a unique name to avoid duplicates:
    rnd_name = 'PyFuncGrad' + str(np.random.randint(0, 1E+8))
    
    tf.RegisterGradient(rnd_name)(grad)
    g = tf.get_default_graph()
    with g.gradient_override_map({"PyFunc": rnd_name}):
        return tf.py_func(func, inp, Tout, stateful=stateful, name=name)
    
def py_logdet(x, name=None):
    
    with ops.op_scope([x], name, "Logdet") as name:
        logdet = py_func(lambda x: np.linalg.slogdet(x)[1],
                         [x],
                         [tf.float64],
                         name=name,
                         grad=_LogdetGrad)  # <-- here's the call to the gradient
    return logdet[0]

def _LogdetGrad(op, grad):
    x = op.inputs[0]
    return tf.matrix_inverse(x) * grad[:, None, None]

# %%
# For sin^2(x/2) Link function
def link_f(f):   # Define Link function
    '''Sinus Squared Link function'''
    pi=0.999*np.pi*tf.ones((N, nr_loci), dtype=tf.float64)  # Matrix - for values bigger than Pi. 
    #Allow for values slightly smaller than Pi to infinte likelihood (to avoid infinities)
    z=0.001*tf.ones((N, nr_loci), dtype=tf.float64)       
    # Matrix - for values smaller than 0. Allow for small values slightly bigger than 1 (to avoid infinities)
    f=tf.where(f>np.pi, pi, f)       # Make values bigger than pi almost pi
    f=tf.where(f<0, z, f)            # Make values smaller than 0 almost 0
    
    y = tf.sin(0.5*f) ** 2        # Do the actual calculation
    return y

with tf.device('/gpu:0'):
    X = tf.Variable(dtype=tf.float64, initial_value = X_data, trainable=False)
    Y = tf.Variable(dtype=tf.float64, initial_value = Y_data, trainable=False)
    F = tf.Variable(dtype=tf.float64, initial_value = np.random.normal(0.0, 0.1, (N, nr_loci)).astype('float64'),
                    trainable=True)

    hyper_params = tf.placeholder(shape = [3 + nr_loci], dtype=tf.float64)      # HyperParameters for the Kernel
    #hyper_params = tf.placeholder(shape=[3], dtype = tf.float64)                # The Kernel Hyper Parameters
    #hyper_params_means =tf.placeholder(shape=[nr_loci], dtype = tf.float64)      # The Mean Hyper Parameters
    
    # First two are for the kernel; nr_loci are for the means of the GRFs!
    #mean_params = tf.placeholder(shape=[nr_loci], dtype=tf.float64)  # HyperParameters for the mean Values
    
    a = tf.abs(hyper_params[0])     # The Parameter for the absolute correlation
    l = tf.abs(hyper_params[1])     # The Parameter for the length scale
    c = tf.abs(hyper_params[2])     # The Parameter for the Barrier strenght
    mean_param = hyper_params[3:]   # The mean parameters
    #mean_param = hyper_params_means
    
    eye = tf.eye(N, dtype=tf.float64)

    # The Kernel for the classical Covariance Matrix
    #K = a * tf.exp(-tf.reduce_sum(((X[:, None] - X[None, :]) ** 2) / (2 * l**2), reduction_indices=[2])) + 0.00001*eye\
    #0.00001 * tf.eye(N, dtype=tf.float64) # Calculate Matrix of Covariances
    
    # The Kernel for the full covariance Matrix:
    K = full_kernel_function(X, l, a, c) + 0.00001 * eye # Add identity to make positive definite
    #K = rbf_kernel_function(X, l, a) + 0.00001 * eye  # Add identity to make positive definite
 
    
    f_tot = F + mean_param[None, :]    # Adds mean term; None is at position of an individual
    #f_tot= F + f_mean[None,:]          # Adds empirical mean term
    #f_tot = F + f_mean                 # For the case that there is a single Value
    p = link_f(f_tot)    # Calculate novel p, assuming sin^2 Link Function
    Kinv_F = tf.matrix_solve(K, F)      # Calculate K^(-1)*F
    
    g0 = tf.greater(Y, 0.5)        # Values where Y is greater than 0; i.e. data is 1.
    g0 = tf.cast(g0, tf.float64)   # Transform so that can be multiplied

    y_f= g0*p + (1-g0)*(1-p)  # Probability of observing y given probabilities p
    
    data_fit = tf.reduce_sum(tf.log(y_f), reduction_indices=[0])   # Calculate Data Fit: Check  
    prior_fit = -0.5 * tf.reduce_sum(F * Kinv_F, reduction_indices=[0])          # Calculate 1st term of prior probability: Check
    
    logL = tf.reduce_sum(data_fit + prior_fit) # Modulo terms not depending on f: Check
    
    d1 = 1.0/tf.tan(0.5*f_tot)   # Gradient coming from f_tot (for y=1)
    d0 = -tf.tan(0.5*f_tot)      # Gradient comfing from t_tot (for y=0)
    
    grad1 = g0*d1 + (1-g0)*d0  # First part of the gradient
    
    g =  grad1 - Kinv_F       # Calculate Matrix for Gradients Check
    
    h1 = -0.5 / ((tf.sin(0.5 * f_tot))**2) # Minus second derivative of data. (for y=1)
    h0 = -1.0 / (1 + tf.cos(f_tot))        # Second derivative of data (for y=0)
    W = - g0 * h1 - (1 - g0) * h0       # Calculate first part of Hessian. It is diagonal (but here diagonal in every column)
    
    lhs = -K[:, :, None] * W[None, :, :] - tf.eye(N, dtype=tf.float64)[:, :, None] # Check (HEAD-ACHE)
    #lhs = -K[:, :, None] * W[None, :, :] - eye[:, :, None] 
    rhs = tf.matmul(K, g)
    
    update = tf.matrix_solve(tf.transpose(lhs, [2, 0, 1]), tf.transpose(rhs, [1, 0])[:, :, None])[:, :, 0]
    update = tf.transpose(update)
    
    opt_op = F.assign(F - update)
    
    #####
    
    B = (W[:, None, :] ** 0.5) * K[:, :, None] * (W[None, :, :] ** 0.5) + tf.eye(N, dtype=tf.float64)[:, :, None]  # Check
    #B = (W[:, None, :] ** 0.5) * K[:, :, None] * (W[None, :, :] ** 0.5) + eye[:, :, None] 
    
    logdet = tf.reduce_sum(py_logdet(tf.transpose(B, [2, 0, 1])))  # Factor of 2??
    
    margL = logL - 0.5 * logdet
    
    ##### Gradients and Hessian #######################3
    
    grad = tf.gradients(margL, hyper_params)
    hessian = tf.hessians(margL, hyper_params)  # Comment out to avoid computational overhead.
# Out:
# WARNING:tensorflow:tf.op_scope(values, name, default_name) is deprecated, use tf.name_scope(name, default_name, values)

# %%
config = tf.ConfigProto()
config.gpu_options.per_process_gpu_memory_fraction = 1.0
config.allow_soft_placement = True

# %%
opt.fmin_l_bfgs_b?

# %%
### Optimization Run with BFGS
#hyper_paramss = np.array([0.02, 15, 0.2]) # The initial values for a & L & c // 0.02 25 0.8
mps = mean_paramss
initial_values = np.array([0.02, 15, 0.1]+list(mps)) # Optimize with the right initial Values

#kk =  np.array([0.012, 20] + f)

with tf.Session(config=config) as sess:
    sess.run(tf.global_variables_initializer())
    
        
    for _ in range(5):   # First optimize the f locally with the initial Values
        _, = sess.run([opt_op], {hyper_params: initial_values})  

    def fg(x):
        print("\nInside Function \n")
        print(x)
        
        for _ in range(5):   # Optimize the f locally
            _, = sess.run([opt_op], {hyper_params: x}) # Optimize for right Hyper_params
        f, g = sess.run([margL, grad], {hyper_params: x})
        print("Likelihood: ")
        print(f)
        return -f, -g[0]
    
    bounds_all_freq = [(None,None) for _ in range(len(mps))]
    result = opt.fmin_l_bfgs_b(fg, initial_values, disp=0,
                               bounds=[(0.0001, 1), (0.01, 100), (0, 1)]+bounds_all_freq)
    hyper_paramss = result[0]
    

    print(['%.4f %.2f %.2f' % (hyper_paramss[0], hyper_paramss[1], hyper_paramss[2])])

    for _ in range(5):   # Optimize the f locally for best fit Parameters.
        _, = sess.run([opt_op], {hyper_params: hyper_paramss}) # Optimize for right Hyper_params
    g, h = sess.run([grad, hessian], {hyper_params: hyper_paramss})
    
    fisher_info = np.matrix(h[0])
    stds = np.sqrt(np.diag(-fisher_info.I)) # Calculates the Standard Deviations (Sqrt of Variance)
    
    print("\nParameter Estimates and Uncertainty: ")
    
    print(hyper_paramss)
    print(stds)
        #if i < 3:  # First three times just run to optimize f_i
        #    continue
        
        #u = np.matmul(np.linalg.inv(h[0]), g[0]) 
        #hyper_paramss -= u
        #print(hyper_paramss, u)
    
    # Code for calculating empirical Fisher-Information Matrix:
#fisher_info = np.matrix(h[0])
#stds = np.sqrt(np.diag(-fisher_info.I)) # Calculates the Standard Deviations (Sqrt of Variance)
#print("Standard Deviations: ")
#print(stds)
# Out:
# Inside Function
#
# [  0.02        15.           0.1          1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633]
# Likelihood:
# -34501.9532951
#
# Inside Function
#
# [  0.01978908  14.9858274    0.0989401    1.62690329   1.66980685
#    1.40711619   1.38750325   1.51631736   1.33766094   1.37491303
#    1.67885713   1.54674518   1.4150574    1.78800966   1.46499805
#    1.58505181   1.63013494   1.59147303   1.51624751   1.62278803
#    1.58522319   1.50554166   1.575434     1.64895529   1.53285043
#    1.65692778   1.45081923   1.60439171   1.50043362   1.55493115
#    1.50782871   1.5376929    1.65483098   1.54204332   1.57484737
#    1.61433258   1.48003169   1.66007895   1.27461614   1.58184562
#    1.44312842   1.73479067   1.5849753    1.64842369   1.61015998
#    1.60059615   1.70014125   1.61255479   1.64754365   1.56437399
#    1.44494972   1.74136516   1.56920712   1.375724     1.76397772
#    1.57621763   1.60840419   1.68716778   1.58362267   1.71961503
#    1.57545373   1.70282249   1.69082401   1.53746341   1.7509034
#    1.45161592   1.48958043   1.58876346   1.65864551   1.74471703
#    1.72565452   1.64478618   1.52269835   1.55694807   1.55513245
#    1.56136135   1.61496861   1.56315231   1.56205047   1.66562522
#    1.47236364   1.43143213   1.54061105   1.47529438   1.49611919
#    1.4515422    1.52776344   1.6292987    1.58567822   1.49877919
#    1.50352649   1.61746941   1.7451251    1.63963543   1.48942749
#    1.57880857   1.63852544   1.70906095   1.49105508   1.46345467
#    1.499489     1.56705844   1.59063062]
# Likelihood:
# -34463.6454861
#
# Inside Function
#
# [  1.00000000e-04   1.49851418e+01   9.81065761e-02   1.62868335e+00
#    1.67294942e+00   1.40192281e+00   1.38168810e+00   1.51458790e+00
#    1.33026206e+00   1.36869558e+00   1.68228680e+00   1.54597913e+00
#    1.41011900e+00   1.79490183e+00   1.46164392e+00   1.58550694e+00
#    1.63201944e+00   1.59212943e+00   1.51451701e+00   1.62443888e+00
#    1.58568070e+00   1.50347014e+00   1.57558234e+00   1.65143675e+00
tf.Session(config=config) as sess:
    sess.run(tf.global_variables_initializer())

    for _ in range(5):   # Optimize the f locally for best fit Parameters.
        _, = sess.run([opt_op], {hyper_params: params}) # Optimize for right Hyper_params
        print("Optimized")
    g, h = sess.run([grad, hessian], {hyper_params: params})

    print("Hessian calculated")
    fisher_info = np.matrix(h[0])
    stds = np.sqrt(np.diag(-fisher_info.I)) # Calculates the Standard Deviations (Sqrt of Variance)

    print("\nParameter Estimates and Uncertainty: ")
    #print(hyper_paramss)
    print(stds)

# %%
mps = mean_paramss
hyper_paramss = [0.02,15,0.5] + list(mean_paramss) # Initial values

with tf.Session(config=config) as sess:
    sess.run(tf.global_variables_initializer())
    
    for j in range(5):
        _ = sess.run([opt_op], {hyper_params: hyper_paramss}) 
    
        
    def f(x):
        print("\nParameters: ")
        print(x)
        
        for i in range(2):
            _, = sess.run([opt_op,], {hyper_params: x})   # Optimize the F 2x (Very fast; quadratic convergence)
            
        f, = sess.run([margL,], {hyper_params: x})    # Calculates the Likelihood
        print("Likelihood: ")
        print(f)
        return -f # Returns the negative function Value

    result = opt.fmin(f, hyper_paramss, disp=1, ftol=1.0)   # Do 1 iteration of bfgs_b
    hyper_paramss_est = np.array([result[0], result[1], result[2]])
    g, h = sess.run([grad, hessian], {hyper_params: hyper_paramss_est})
    
    fisher_info = np.matrix(h[0])
    stds = np.sqrt(np.diag(-fisher_info.I)) # Calculates the Standard Deviations (Sqrt of Variance)
    
    res=result[:3]
    print(res)
    print(stds)
# Out:
# Parameters:
# [  0.02        15.           0.5          1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633]
# Likelihood:
# -27631.4951882
#
# Parameters:
# [  0.021       15.           0.5          1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633]
# Likelihood:
# -27632.9639564
#
# Parameters:
# [  0.02        15.75         0.5          1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633]
# Likelihood:
# -27632.8450343
#
# Parameters:
# [  0.02        15.           0.525        1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633]
# Likelihood:
# -27632.309018
#
# Parameters:
# [  0.02        15.           0.5          1.64933614   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633]
# Likelihood:
# -27631.7371768
#
# Parameters:
# [  0.02        15.           0.5          1.57079633   1.64933614
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633]
# Likelihood:
# -27631.0523791
#
# Parameters:
# [  0.02        15.           0.5          1.57079633   1.57079633
#    1.64933614   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633]
# Likelihood:
# -27633.0477119
#
# Parameters:
# [  0.02        15.           0.5          1.57079633   1.57079633
#    1.57079633   1.64933614   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633]
# Likelihood:
# -27633.2828673
#
# Parameters:
# [  0.02        15.           0.5          1.57079633   1.57079633
#    1.57079633   1.57079633   1.64933614   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633]
# Likelihood:
# -27632.1029049
#
# Parameters:
# [  0.02        15.           0.5          1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.64933614   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633]
# Likelihood:
# -27633.2875711
#
# Parameters:
# [  0.02        15.           0.5          1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.64933614
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633]
# Likelihood:
# -27633.034822
#
# Parameters:
# [  0.02        15.           0.5          1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.64933614   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633]
# Likelihood:
# -27631.1818727
#
# Parameters:
# [  0.02        15.           0.5          1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.64933614   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633]
# Likelihood:
# -27632.0154951
#
# Parameters:
# [  0.02        15.           0.5          1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.64933614   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633]
# Likelihood:
# -27632.5764646
#
# Parameters:
# [  0.02        15.           0.5          1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.64933614   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633]
# Likelihood:
# -27630.1226542
#
# Parameters:
# [  0.02        15.           0.5          1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.64933614
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633]
# Likelihood:
# -27632.3581996
#
# Parameters:
# [  0.02        15.           0.5          1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.64933614   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633]
# Likelihood:
# -27631.5494763
#
# Parameters:
# [  0.02        15.           0.5          1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.64933614   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633]
# Likelihood:
# -27631.4516649
#
# Parameters:
# [  0.02        15.           0.5          1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.64933614   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633   1.57079633   1.57079633
#    1.57079633   1.57079633   1.57079633]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-c1eb84a09ec6> in <module>()
#      21         return -f # Returns the negative function Value
#      22
# ---> 23     result = opt.fmin(f, hyper_paramss, disp=1, ftol=1.0)   # Do 1 iteration of bfgs_b
#      24     hyper_paramss_est = np.array([result[0], result[1], result[2]])
#      25     g, h = sess.run([grad, hessian], {hyper_params: hyper_paramss_est})
#
# /usr/local/lib/python2.7/dist-packages/scipy/optimize/optimize.pyc in fmin(func, x0, args, xtol, ftol, maxiter, maxfun, full_output, disp, retall, callback, initial_simplex)
#     391             'initial_simplex': initial_simplex}
#     392
# --> 393     res = _minimize_neldermead(func, x0, args, callback=callback, **opts)
#     394     if full_output:
#     395         retlist = res['x'], res['fun'], res['nit'], res['nfev'], res['status']
#
# /usr/local/lib/python2.7/dist-packages/scipy/optimize/optimize.pyc in _minimize_neldermead(func, x0, args, callback, maxiter, maxfev, disp, return_all, initial_simplex, xatol, fatol, **unknown_options)
#     515
#     516     for k in range(N + 1):
# --> 517         fsim[k] = func(sim[k])
#     518
#     519     ind = numpy.argsort(fsim)
#
# /usr/local/lib/python2.7/dist-packages/scipy/optimize/optimize.pyc in function_wrapper(*wrapper_args)
#     290     def function_wrapper(*wrapper_args):
#     291         ncalls[0] += 1
# --> 292         return function(*(wrapper_args + args))
#     293
#     294     return ncalls, function_wrapper
#
# <ipython-input-13-c1eb84a09ec6> in f(x)
#      14
#      15         for i in range(2):
# ---> 16             _, = sess.run([opt_op,], {hyper_params: x})   # Optimize the F 2x (Very fast; quadratic convergence)
#      17
#      18         f, = sess.run([margL,], {hyper_params: x})    # Calculates the Likelihood
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     764     try:
#     765       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 766                          run_metadata_ptr)
#     767       if run_metadata:
#     768         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     962     if final_fetches or final_targets:
#     963       results = self._do_run(handle, final_targets, final_fetches,
# --> 964                              feed_dict_string, options, run_metadata)
#     965     else:
#     966       results = []
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1012     if handle is None:
#    1013       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1014                            target_list, options, run_metadata)
#    1015     else:
#    1016       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1019   def _do_call(self, fn, *args):
#    1020     try:
# -> 1021       return fn(*args)
#    1022     except errors.OpError as e:
#    1023       message = compat.as_text(e.message)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1001         return tf_session.TF_Run(session, options,
#    1002                                  feed_dict, fetch_list, target_list,
# -> 1003                                  status, run_metadata)
#    1004
#    1005     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
with tf.Session(config=config) as sess:
    sess.run(tf.global_variables_initializer())
    
    for i in range(10):
        tic = time.time()
        sess.run(margL, {hyper_params: [1.0, 1.0, 1.0], hyper_params_means: np.zeros(nr_loci)})
        toc = time.time()
        t1 = toc - tic
        
        tic = time.time()
        sess.run(grad, {hyper_params: [1.0, 1.0, 1.0], hyper_params_means: np.zeros(nr_loci)})
        toc = time.time()
        t2 = toc - tic
        
        tic = time.time()
        sess.run(hessian, {hyper_params: [1.0, 1.0, 1.0], hyper_params_means: np.zeros(nr_loci)})
        toc = time.time()
        t3 = toc - tic
        
        print(t1, t2, t3)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-3233818ba869> in <module>()
#      14
#      15         tic = time.time()
# ---> 16         sess.run(hessian, {hyper_params: [1.0, 1.0, 1.0], hyper_params_means: np.zeros(nr_loci)})
#      17         toc = time.time()
#      18         t3 = toc - tic
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     764     try:
#     765       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 766                          run_metadata_ptr)
#     767       if run_metadata:
#     768         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     962     if final_fetches or final_targets:
#     963       results = self._do_run(handle, final_targets, final_fetches,
# --> 964                              feed_dict_string, options, run_metadata)
#     965     else:
#     966       results = []
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1012     if handle is None:
#    1013       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1014                            target_list, options, run_metadata)
#    1015     else:
#    1016       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1019   def _do_call(self, fn, *args):
#    1020     try:
# -> 1021       return fn(*args)
#    1022     except errors.OpError as e:
#    1023       message = compat.as_text(e.message)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1001         return tf_session.TF_Run(session, options,
#    1002                                  feed_dict, fetch_list, target_list,
# -> 1003                                  status, run_metadata)
#    1004
#    1005     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
for i in range(len(hyper_paramss)):
    print("Hyperparameter %i: " %i)
    print("MLE Estimate: %.6f" % hyper_paramss[i])
    print("Standard Deviation: %.6f" % stds[i])
# Out:
# Hyperparameter 0:
# MLE Estimate: 0.020000
# Standard Deviation: 0.001375
# Hyperparameter 1:
# MLE Estimate: 15.000000
# Standard Deviation: 0.318775
# Hyperparameter 2:
# MLE Estimate: 0.500000
# Standard Deviation: 0.033064

# %%
#a_list = np.logspace(-1.5, -0.5, 10)   # Original Values

a_list=np.logspace(-3,-1.5,10)
l_list = np.logspace(0.5, 2, 10)
#c_list = np.logspace(-0.4, 0, 10)
c_list =np.linspace(0,1,10)

#a_list = np.logspace(-3, -0.5, 10)
#l_list = np.logspace(0, 2, 10)


print(a_list)
print(l_list)
print(c_list)
# Out:
# [ 0.001       0.0014678   0.00215443  0.00316228  0.00464159  0.00681292
#   0.01        0.01467799  0.02154435  0.03162278]
# [   3.16227766    4.64158883    6.81292069   10.           14.67799268
#    21.5443469    31.6227766    46.41588834   68.12920691  100.        ]
# [ 0.          0.11111111  0.22222222  0.33333333  0.44444444  0.55555556
#   0.66666667  0.77777778  0.88888889  1.        ]

# %%
res = []
j=0
print("Mean Parameters: ")
print(mean_paramss[:10])
with tf.Session(config=config) as sess:
    aa = 0.02  # The true Value
    #cc = 0.0 # The value for the barrier
    #for aa in a_list:
    for cc in c_list:  # Replaced aa with cc
        for ll in l_list:
            print("Doing run: %i" % j)
            j+=1
    
            sess.run(tf.global_variables_initializer())   # Changed to global_variables_initializer

            prev = None
            for i in range(20):
                #hyper_paramss = np.array([aa,ll])
                #hyper_paramss = np.append(hyper_paramss, mean_paramss)
                
                hyper_paramss = np.array([aa, ll, cc])
                #hyper_paramss = np.append(hyper_paramss, mean_paramss)
                
                r = sess.run([opt_op, update, logL, margL], {hyper_params: hyper_paramss, hyper_params_means: mean_paramss})
                if prev and np.abs(prev - r[-1]) < 0.01:
                    break
                prev = r[-1]
            print("Tested a: %4f" % aa)
            print("Tested l: %4f" % ll)
            print("Tested c: %4f" % cc)
            print("Marginal Likelihood: %4f" % r[-1])
            res.append(r[-1])
# Out:
# Mean Parameters:
# [ 1.57079633  1.57079633  1.57079633  1.57079633  1.57079633  1.57079633
#   1.57079633  1.57079633  1.57079633  1.57079633]
# Doing run: 0
# Tested a: 0.001000
# Tested l: 3.162278
# Tested c: 0.000000
# Marginal Likelihood: -13862.064259
# Doing run: 1
# Tested a: 0.001000
# Tested l: 4.641589
# Tested c: 0.000000
# Marginal Likelihood: -13861.352264
# Doing run: 2
# Tested a: 0.001000
# Tested l: 6.812921
# Tested c: 0.000000
# Marginal Likelihood: -13860.066023
# Doing run: 3
# Tested a: 0.001000
# Tested l: 10.000000
# Tested c: 0.000000
# Marginal Likelihood: -13858.438196
# Doing run: 4
# Tested a: 0.001000
# Tested l: 14.677993
# Tested c: 0.000000
# Marginal Likelihood: -13857.062563
# Doing run: 5
# Tested a: 0.001000
# Tested l: 21.544347
# Tested c: 0.000000
# Marginal Likelihood: -13856.236823
# Doing run: 6
# Tested a: 0.001000
# Tested l: 31.622777
# Tested c: 0.000000
# Marginal Likelihood: -13855.882882
# Doing run: 7
# Tested a: 0.001000
# Tested l: 46.415888
# Tested c: 0.000000
# Marginal Likelihood: -13855.785802
# Doing run: 8
# Tested a: 0.001000
# Tested l: 68.129207
# Tested c: 0.000000
# Marginal Likelihood: -13855.777326
# Doing run: 9
# Tested a: 0.001000
# Tested l: 100.000000
# Tested c: 0.000000
# Marginal Likelihood: -13855.785893
# Doing run: 10
# Tested a: 0.001468
# Tested l: 3.162278
# Tested c: 0.000000
# Marginal Likelihood: -13861.661280
# Doing run: 11
# Tested a: 0.001468
# Tested l: 4.641589
# Tested c: 0.000000
# Marginal Likelihood: -13860.635173
# Doing run: 12
# Tested a: 0.001468
# Tested l: 6.812921
# Tested c: 0.000000
# Marginal Likelihood: -13858.793351
# Doing run: 13
# Tested a: 0.001468
# Tested l: 10.000000
# Tested c: 0.000000
# Marginal Likelihood: -13856.500642
# Doing run: 14
# Tested a: 0.001468
# Tested l: 14.677993
# Tested c: 0.000000
# Marginal Likelihood: -13854.650159
# Doing run: 15
# Tested a: 0.001468
# Tested l: 21.544347
# Tested c: 0.000000
# Marginal Likelihood: -13853.669742
# Doing run: 16
# Tested a: 0.001468
# Tested l: 31.622777
# Tested c: 0.000000
# Marginal Likelihood: -13853.385099
# Doing run: 17
# Tested a: 0.001468
# Tested l: 46.415888
# Tested c: 0.000000
# Marginal Likelihood: -13853.420900
# Doing run: 18
# Tested a: 0.001468
# Tested l: 68.129207
# Tested c: 0.000000
# Marginal Likelihood: -13853.517833
# Doing run: 19
# Tested a: 0.001468
# Tested l: 100.000000
# Tested c: 0.000000
# Marginal Likelihood: -13853.589154
# Doing run: 20
# Tested a: 0.002154
# Tested l: 3.162278
# Tested c: 0.000000
# Marginal Likelihood: -13861.079349
# Doing run: 21
# Tested a: 0.002154
# Tested l: 4.641589
# Tested c: 0.000000
# Marginal Likelihood: -13859.613425
# Doing run: 22
# Tested a: 0.002154
# Tested l: 6.812921
# Tested c: 0.000000
# Marginal Likelihood: -13857.006322
# Doing run: 23
# Tested a: 0.002154
# Tested l: 10.000000
# Tested c: 0.000000
# Marginal Likelihood: -13853.837184
# Doing run: 24
# Tested a: 0.002154
# Tested l: 14.677993
# Tested c: 0.000000
# Marginal Likelihood: -13851.446902
# Doing run: 25
# Tested a: 0.002154
# Tested l: 21.544347
# Tested c: 0.000000
# Marginal Likelihood: -13850.426143
# Doing run: 26
# Tested a: 0.002154
# Tested l: 31.622777
# Tested c: 0.000000
# Marginal Likelihood: -13850.405017
# Doing run: 27
# Tested a: 0.002154
# Tested l: 46.415888
# Tested c: 0.000000
# Marginal Likelihood: -13850.745151
# Doing run: 28
# Tested a: 0.002154
# Tested l: 68.129207
# Tested c: 0.000000
# Marginal Likelihood: -13851.060109
# Doing run: 29
# Tested a: 0.002154
# Tested l: 100.000000
# Tested c: 0.000000
# Marginal Likelihood: -13851.256841
# Doing run: 30
# Tested a: 0.003162
# Tested l: 3.162278
# Tested c: 0.000000
# Marginal Likelihood: -13860.245560
# Doing run: 31
# Tested a: 0.003162
# Tested l: 4.641589
# Tested c: 0.000000
# Marginal Likelihood: -13858.178458
# Doing run: 32
# Tested a: 0.003162
# Tested l: 6.812921
# Tested c: 0.000000
# Marginal Likelihood: -13854.550128
# Doing run: 33
# Tested a: 0.003162
# Tested l: 10.000000
# Tested c: 0.000000
# Marginal Likelihood: -13850.286344
# Doing run: 34
# Tested a: 0.003162
# Tested l: 14.677993
# Tested c: 0.000000
# Marginal Likelihood: -13847.379445
# Doing run: 35
# Tested a: 0.003162
# Tested l: 21.544347
# Tested c: 0.000000
# Marginal Likelihood: -13846.583929
# Doing run: 36
# Tested a: 0.003162
# Tested l: 31.622777
# Tested c: 0.000000
# Marginal Likelihood: -13847.158334
# Doing run: 37
# Tested a: 0.003162
# Tested l: 46.415888
# Tested c: 0.000000
# Marginal Likelihood: -13848.068499
# Doing run: 38
# Tested a: 0.003162
# Tested l: 68.129207
# Tested c: 0.000000
# Marginal Likelihood: -13848.770958
# Doing run: 39
# Tested a: 0.003162
# Tested l: 100.000000
# Tested c: 0.000000
# Marginal Likelihood: -13849.186981
# Doing run: 40
# Tested a: 0.004642
# Tested l: 3.162278
# Tested c: 0.000000
# Marginal Likelihood: -13859.064870
# Doing run: 41
# Tested a: 0.004642
# Tested l: 4.641589
# Tested c: 0.000000
# Marginal Likelihood: -13856.206879
# Doing run: 42
# Tested a: 0.004642
# Tested l: 6.812921
# Tested c: 0.000000
# Marginal Likelihood: -13851.281732
# Doing run: 43
# Tested a: 0.004642
# Tested l: 10.000000
# Tested c: 0.000000
# Marginal Likelihood: -13845.763502
# Doing run: 44
# Tested a: 0.004642
# Tested l: 14.677993
# Tested c: 0.000000
# Marginal Likelihood: -13842.540596
# Doing run: 45
# Tested a: 0.004642
# Tested l: 21.544347
# Tested c: 0.000000
# Marginal Likelihood: -13842.441957
# Doing run: 46
# Tested a: 0.004642
# Tested l: 31.622777
# Tested c: 0.000000
# Marginal Likelihood: -13844.083530
# Doing run: 47
# Tested a: 0.004642
# Tested l: 46.415888
# Tested c: 0.000000
# Marginal Likelihood: -13845.908330
# Doing run: 48
# Tested a: 0.004642
# Tested l: 68.129207
# Tested c: 0.000000
# Marginal Likelihood: -13847.215497
# Doing run: 49
# Tested a: 0.004642
# Tested l: 100.000000
# Tested c: 0.000000
# Marginal Likelihood: -13847.972896
# Doing run: 50
# Tested a: 0.006813
# Tested l: 3.162278
# Tested c: 0.000000
# Marginal Likelihood: -13857.422531
# Doing run: 51
# Tested a: 0.006813
# Tested l: 4.641589
# Tested c: 0.000000
# Marginal Likelihood: -13853.588648
# Doing run: 52
# Tested a: 0.006813
# Tested l: 6.812921
# Tested c: 0.000000
# Marginal Likelihood: -13847.145919
# Doing run: 53
# Tested a: 0.006813
# Tested l: 10.000000
# Tested c: 0.000000
# Marginal Likelihood: -13840.391082
# Doing run: 54
# Tested a: 0.006813
# Tested l: 14.677993
# Tested c: 0.000000
# Marginal Likelihood: -13837.327399
# Doing run: 55
# Tested a: 0.006813
# Tested l: 21.544347
# Tested c: 0.000000
# Marginal Likelihood: -13838.598278
# Doing run: 56
# Tested a: 0.006813
# Tested l: 31.622777
# Tested c: 0.000000
# Marginal Likelihood: -13841.840855
# Doing run: 57
# Tested a: 0.006813
# Tested l: 46.415888
# Tested c: 0.000000
# Marginal Likelihood: -13844.931581
# Doing run: 58
# Tested a: 0.006813
# Tested l: 68.129207
# Tested c: 0.000000
# Marginal Likelihood: -13847.070768
# Doing run: 59
# Tested a: 0.006813
# Tested l: 100.000000
# Tested c: 0.000000
# Marginal Likelihood: -13848.305281
# Doing run: 60
# Tested a: 0.010000
# Tested l: 3.162278
# Tested c: 0.000000
# Marginal Likelihood: -13855.200309
# Doing run: 61
# Tested a: 0.010000
# Tested l: 4.641589
# Tested c: 0.000000
# Marginal Likelihood: -13850.297385
# Doing run: 62
# Tested a: 0.010000
# Tested l: 6.812921
# Tested c: 0.000000
# Marginal Likelihood: -13842.326418
# Doing run: 63
# Tested a: 0.010000
# Tested l: 10.000000
# Tested c: 0.000000
# Marginal Likelihood: -13834.699996
# Doing run: 64
# Tested a: 0.010000
# Tested l: 14.677993
# Tested c: 0.000000
# Marginal Likelihood: -13832.585537
# Doing run: 65
# Tested a: 0.010000
# Tested l: 21.544347
# Tested c: 0.000000
# Marginal Likelihood: -13835.970780
# Doing run: 66
# Tested a: 0.010000
# Tested l: 31.622777
# Tested c: 0.000000
# Marginal Likelihood: -13841.232948
# Doing run: 67
# Tested a: 0.010000
# Tested l: 46.415888
# Tested c: 0.000000
# Marginal Likelihood: -13845.815330
# Doing run: 68
# Tested a: 0.010000
# Tested l: 68.129207
# Tested c: 0.000000
# Marginal Likelihood: -13848.958299
# Doing run: 69
# Tested a: 0.010000
# Tested l: 100.000000
# Tested c: 0.000000
# Marginal Likelihood: -13850.795450
# Doing run: 70
# Tested a: 0.014678
# Tested l: 3.162278
# Tested c: 0.000000
# Marginal Likelihood: -13852.323535
# Doing run: 71
# Tested a: 0.014678
# Tested l: 4.641589
# Tested c: 0.000000
# Marginal Likelihood: -13846.536951
# Doing run: 72
# Tested a: 0.014678
# Tested l: 6.812921
# Tested c: 0.000000
# Marginal Likelihood: -13837.500790
# Doing run: 73
# Tested a: 0.014678
# Tested l: 10.000000
# Tested c: 0.000000
# Marginal Likelihood: -13829.878717
# Doing run: 74
# Tested a: 0.014678
# Tested l: 14.677993
# Tested c: 0.000000
# Marginal Likelihood: -13829.699911
# Doing run: 75
# Tested a: 0.014678
# Tested l: 21.544347
# Tested c: 0.000000
# Marginal Likelihood: -13835.739425
# Doing run: 76
# Tested a: 0.014678
# Tested l: 31.622777
# Tested c: 0.000000
# Marginal Likelihood: -13843.087141
# Doing run: 77
# Tested a: 0.014678
# Tested l: 46.415888
# Tested c: 0.000000
# Marginal Likelihood: -13849.098903
# Doing run: 78
# Tested a: 0.014678
# Tested l: 68.129207
# Tested c: 0.000000
# Marginal Likelihood: -13853.277629
# Doing run: 79
# Tested a: 0.014678
# Tested l: 100.000000
# Tested c: 0.000000
# Marginal Likelihood: -13855.803902
# Doing run: 80
# Tested a: 0.021544
# Tested l: 3.162278
# Tested c: 0.000000
# Marginal Likelihood: -13848.869192
# Doing run: 81
# Tested a: 0.021544
# Tested l: 4.641589
# Tested c: 0.000000
# Marginal Likelihood: -13843.006971
# Doing run: 82
# Tested a: 0.021544
# Tested l: 6.812921
# Tested c: 0.000000
# Marginal Likelihood: -13834.197937
# Doing run: 83
# Tested a: 0.021544
# Tested l: 10.000000
# Tested c: 0.000000
# Marginal Likelihood: -13827.991778
# Doing run: 84
# Tested a: 0.021544
# Tested l: 14.677993
# Tested c: 0.000000
# Marginal Likelihood: -13830.573063
# Doing run: 85
# Tested a: 0.021544
# Tested l: 21.544347
# Tested c: 0.000000
# Marginal Likelihood: -13839.236513
# Doing run: 86
# Tested a: 0.021544
# Tested l: 31.622777
# Tested c: 0.000000
# Marginal Likelihood: -13848.180975
# Doing run: 87
# Tested a: 0.021544
# Tested l: 46.415888
# Tested c: 0.000000
# Marginal Likelihood: -13855.130869
# Doing run: 88
# Tested a: 0.021544
# Tested l: 68.129207
# Tested c: 0.000000
# Marginal Likelihood: -13860.141590
# Doing run: 89
# Tested a: 0.021544
# Tested l: 100.000000
# Tested c: 0.000000
# Marginal Likelihood: -13863.367857
# Doing run: 90
# Tested a: 0.031623
# Tested l: 3.162278
# Tested c: 0.000000
# Marginal Likelihood: -13845.280713
# Doing run: 91
# Tested a: 0.031623
# Tested l: 4.641589
# Tested c: 0.000000
# Marginal Likelihood: -13841.316377
# Doing run: 92
# Tested a: 0.031623
# Tested l: 6.812921
# Tested c: 0.000000
# Marginal Likelihood: -13835.185441
# Doing run: 93
# Tested a: 0.031623
# Tested l: 10.000000
# Tested c: 0.000000
# Marginal Likelihood: -13832.050209
# Doing run: 94
# Tested a: 0.031623
# Tested l: 14.677993
# Tested c: 0.000000
# Marginal Likelihood: -13837.478045
# Doing run: 95
# Tested a: 0.031623
# Tested l: 21.544347
# Tested c: 0.000000
# Marginal Likelihood: -13847.832025
# Doing run: 96
# Tested a: 0.031623
# Tested l: 31.622777
# Tested c: 0.000000
# Marginal Likelihood: -13857.249023
# Doing run: 97
# Tested a: 0.031623
# Tested l: 46.415888
# Tested c: 0.000000
# Marginal Likelihood: -13864.153241
# Doing run: 98
# Tested a: 0.031623
# Tested l: 68.129207
# Tested c: 0.000000
# Marginal Likelihood: -13869.452849
# Doing run: 99
# Tested a: 0.031623
# Tested l: 100.000000
# Tested c: 0.000000
# Marginal Likelihood: -13873.256230

# %%
surface = np.array(res).reshape((10, 10))
pylab.pcolormesh(l_list, a_list, surface)
#pylab.pcolormesh(, a_list, surface)
pylab.xscale('log')
#pylab.yscale('log')
pylab.xlabel('l')
pylab.ylabel('a')
pylab.colorbar()
#pylab.plot(25, 0.1, 'ko', linewidth=5)
pylab.plot(15, 0.02, 'ko', linewidth=5)

# %%
pylab.figure()
levels = np.arange(max(res) - 30, max(res) + 1, 2)  # Every two likelihood units
#ax=pylab.contourf(l_list, a_list, surface, alpha=0.9, levels=levels)
ax=pylab.contourf(l_list, a_list, surface, alpha=0.9,levels=levels)

# plt.clabel(ax, inline=1, fontsize=10)
cb=pylab.colorbar(ax, format="%i")
cb.ax.tick_params(labelsize=16)
pylab.title("Log Likelihood Surface", fontsize=20)
pylab.xlabel("Parameter 1", fontsize=20) # l
pylab.ylabel("Parameter 2", fontsize=20) # a
pylab.xticks(fontsize=16)
pylab.yticks(fontsize=16)
pylab.xscale('log')
pylab.tick_params(axis='both', which='both', bottom='off', 
                    top='off', labelbottom='off', right='off', left='off', labelleft='off')
#pylab.yscale('log')
pylab.plot(15, 0.02, 'ko', linewidth=5, label="True Value")
pylab.legend()
pylab.tight_layout()
pylab.show()

# %%
aa, ll = 1, 1
kk = np.array([1, 1, 0.8])   #a,l,c
kk = np.append(kk, mean_paramss)
print("Hyper Parameters: ")
print(kk[:10])

# %%
# Single Run; where optimization is computed.
with tf.Session(config=config) as sess:
    #sess.run(tf.initialize_all_variables())
    sess.run(tf.global_variables_initializer())   # Update by Harald
    
    for i in range(5):
        sess.run(opt_op, {hyper_params: kk})
    r = sess.run([f_tot, F, logdet, margL, K], {hyper_params: kk})
print("f_tot:")
print(r[0])
print("F:")
print(r[1])
print("logdet:")
print(r[2])
print("Marg.L")
print(r[3])
print("K")
print(r[4])

# %%
x, y, z = X_data[:nr_inds, 0], X_data[:nr_inds, 1], r[0][:,1]
#x=np.linspace(0, 1, 20)
#print(len(x))
print(len(x))
print(len(y))
print(len(z))

# %%
pylab.pcolormesh(x, y, z.reshape(21,21))
pylab.colorbar()

# %%
x.shape

# %%
y.shape

# %%
z.shape

# %%
961 ** 0.5

# %%
with tf.device('/cpu:0'):
    X = tf.Variable(dtype=tf.float64, initial_value = 0, trainable=False)

# %%
with tf.device('/cpu:0'):   # For debugging
    c = 3*tf.ones((5,2), dtype=tf.float64)
    d = tf.constant([-1,1], dtype=tf.float64)
    e= c * d[None,:]
    f = c[:,0]

# %%
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    r=sess.run([c,d,e,f])

# %%
r[-1]

# %%
tf.__version__

# %%
logdet

# %%
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    r = sess.run(logdet, {a: 1.0, l: 1.0})

# %%
r
